# %% [markdown]
# Python is a popular programming language.
#
# Created by Guido van Rossum.
#
# Its syntax is simple and readable.

# %%
#First and Basic python code. Printing Hello World
print("Hello World")
# Out:
# Hello World

# %%
#Check the version of Python editor
import sys
print(sys.version)
# Out:
# 3.13.14 (tags/v3.13.14:fd17997, Jun 10 2026, 13:03:48) [MSC v.1944 64 bit (AMD64)]
