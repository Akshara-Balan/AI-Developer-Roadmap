# %% [markdown]
# Keywords in python
#
# Reserved words in python.
# Words that have very special meaning to python.
#
# False
# None
# True
# and
# as
# assert
# async
# await
# break
# class
# continue
# def
# del
# elif
# else
# except
# finally
# for
# from
# global
# if
# import
# inis
# lambda
# nonlocal
# not
# or
# pass
# raise
# return
# try
# while
# with
# yield
